# %%
# %load_ext autoreload
# %autoreload 2

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
import sys
sys.path.insert(0, '/usr/src/scripts')

# %%
from etl import ETL

# %%
etl = ETL()
df = etl.fit('migraine-classification/data.csv')

# %%
import yaml

# %%
with open("/usr/src/configs/experiment-1.yaml", 'r') as yaml_file:
    cfg = yaml.load(yaml_file, Loader=yaml.FullLoader)

# %%
cfg
# Out:
# {'experiment_name': 'migraine-classification',
#  'datasets': {'path': 'migraine-classification/data.csv',
#   'x': ['age',
#    'duration',
#    'frequency',
#    'location',
#    'character',
#    'intensity',
#    'nausea',
#    'vomit',
#    'phonophobia',
#    'photophobia',
#    'visual',
#    'sensory',
#    'dysphasia',
#    'dysarthria',
#    'vertigo',
#    'tinnitus',
#    'hypoacusis',
#    'diplopia',
#    'defect',
#    'ataxia',
#    'conscience',
#    'paresthesia',
#    'dpf'],
#   'y': ['Type'],
#   'train_test_split': {'test_size': 0.3, 'random_state': 696},
#   'labels': ['Typical aura with migraine',
#    'Migraine without aura',
#    'Basilar-type aura',
#    'Sporadic hemiplegic migraine',
#    'Familial hemiplegic migraine',
#    'Other',
#    'Typical aura without migraine']},
#  'models': {'sklearn': {'neural_network': ['MLPClassifier'],
#    'neighbors': ['KNeighborsClassifier'],
#    'svm': ['SVC'],
#    'gaussian_process': ['GaussianProcessClassifier'],
#    'gaussian_process_kernels': ['RBF'],
#    'tree': ['DecisionTreeClassifier'],
#    'ensemble': ['RandomForestClassifier', 'AdaBoostClassifier'],
#    'naive_bayes': ['GaussianNB'],
#    'discriminant_analysis': ['QuadraticDiscriminantAnalysis'],
#    'inspection': ['DecisionBoundaryDisplay']},
#   'epochs': 10}}

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df[cfg['datasets']['x']], df[cfg['datasets']['y']], test_size=float(cfg['datasets']['train_test_split']['test_size']), random_state=696)

# %%
rf = RandomForestClassifier()

# %%
rf.fit(x_train, y_train)
# Out:
# /tmp/ipykernel_435/3512478466.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train, y_train)
# RandomForestClassifier()

# %%
from sklearn.metrics import classification_report

# %%
classification_report(y_test, rf.predict(x_test), labels=cfg['datasets']['labels'], target_names=cfg['datasets']['labels'], output_dict=True)
# Out:
# '                               precision    recall  f1-score   support\n\n   Typical aura with migraine       0.87      1.00      0.93        67\n        Migraine without aura       1.00      1.00      1.00        19\n            Basilar-type aura       0.83      0.83      0.83         6\n Sporadic hemiplegic migraine       1.00      0.20      0.33         5\n Familial hemiplegic migraine       0.40      0.33      0.36         6\n                        Other       1.00      0.50      0.67        10\nTypical aura without migraine       1.00      1.00      1.00         7\n\n                     accuracy                           0.88       120\n                    macro avg       0.87      0.70      0.73       120\n                 weighted avg       0.89      0.88      0.87       120\n'

# %%
type(report)
# Out:
# str

# %%
report
# Out:
# '                               precision    recall  f1-score   support\n\n            Basilar-type aura       0.83      0.83      0.83         6\n Familial hemiplegic migraine       0.40      0.33      0.36         6\n        Migraine without aura       1.00      1.00      1.00        19\n                        Other       1.00      0.50      0.67        10\n Sporadic hemiplegic migraine       1.00      0.20      0.33         5\n   Typical aura with migraine       0.87      1.00      0.93        67\nTypical aura without migraine       1.00      1.00      1.00         7\n\n                     accuracy                           0.88       120\n                    macro avg       0.87      0.70      0.73       120\n                 weighted avg       0.89      0.88      0.87       120\n'
