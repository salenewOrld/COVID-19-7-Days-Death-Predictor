# %%
import pandas as pd

# %%
pd.read_csv('/usr/src/datasets/owid/owid-covid-data.csv')
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 206392      ZWE    Africa     Zimbabwe  2022-07-31     256378.0        2.0
# 206393      ZWE    Africa     Zimbabwe  2022-08-01     256382.0        4.0
# 206394      ZWE    Africa     Zimbabwe  2022-08-02     256403.0       21.0
# 206395      ZWE    Africa     Zimbabwe  2022-08-03     256423.0       20.0
# 206396      ZWE    Africa     Zimbabwe  2022-08-04     256444.0       21.0
#
# ...
